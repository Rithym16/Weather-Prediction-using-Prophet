# %% [markdown]
# //DEVELOPED BY RITHYM GULATI

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


# Load the data
df = pd.read_csv('/content/lucknowweather.csv')

# Convert 'time' column to datetime format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15817 entries, 0 to 15816
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  15817 non-null  object
#  1   NAME     15817 non-null  object
#  2   DATE     15817 non-null  object
#  3   PRCP     8682 non-null   float64
#  4   TAVG     15817 non-null  int64
#  5   TMAX     13245 non-null  float64
#  6   TMIN     10921 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 865.1+ KB

# %%
df.describe()
# Out:
#               PRCP          TAVG          TMAX          TMIN
# count  8682.000000  15817.000000  13245.000000  10921.000000
# mean      0.160426     77.043624     90.094602     65.071514
# std       0.617199     12.013249     11.109952     13.023658
# min       0.000000     42.000000     52.000000     31.000000
# 25%       0.000000     67.000000     82.000000     53.000000
# 50%       0.000000     80.000000     91.000000     68.000000
# 75%       0.020000     86.000000     97.000000     77.000000
# max      18.540000    103.000000    117.000000     91.000000

# %%
sns.histplot(df['TAVG'],kde=True)
# Out:
# <Axes: xlabel='TAVG', ylabel='Count'>

# %%
tf=df['DATE']

# %%
tf.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15817 entries, 0 to 15816
# Series name: DATE
# Non-Null Count  Dtype
# --------------  -----
# 15817 non-null  object
# dtypes: object(1)
# memory usage: 123.7+ KB

# %%
tf.describe()
# Out:
# count          15817
# unique         15817
# top       1980-01-01
# freq               1
# Name: DATE, dtype: object

# %%
tf.head()
# Out:
# 0    1980-01-01
# 1    1980-01-02
# 2    1980-01-03
# 3    1980-01-04
# 4    1980-01-05
# Name: DATE, dtype: object

# %%
# Assuming df is your DataFrame and 'DATE' is the column name
df['DATE'] = pd.to_datetime(df['DATE'])

df['day'] = df['DATE'].dt.day
df['month'] = df['DATE'].dt.month
df['year'] = df['DATE'].dt.year

# %%
df.describe()
# Out:
#                                 DATE         PRCP          TAVG          TMAX  \
# count                          15817  8682.000000  15817.000000  13245.000000
# mean   2002-06-13 22:14:28.989062528     0.160426     77.043624     90.094602
# min              1980-01-01 00:00:00     0.000000     42.000000     52.000000
# 25%              1991-08-19 00:00:00     0.000000     67.000000     82.000000
# 50%              2002-08-21 00:00:00     0.000000     80.000000     91.000000
# 75%              2013-06-22 00:00:00     0.020000     86.000000     97.000000
# max              2024-05-03 00:00:00    18.540000    103.000000    117.000000
# std                              NaN     0.617199     12.013249     11.109952
#
#                TMIN           day         month          year
# count  10921.000000  15817.000000  15817.000000  15817.000000
# mean      65.071514     15.715875      6.503066   2001.952203
# min       31.000000      1.000000      1.000000   1980.000000
# 25%       53.000000      8.000000      3.000000   1991.000000
# 50%       68.000000     16.000000      7.000000   2002.000000
# 75%       77.000000     23.000000     10.000000   2013.000000
# max       91.000000     31.000000     12.000000   2024.000000
# std       13.023658      8.786842      3.458677     12.771586

# %%
df.drop(['TMIN','TMAX','PRCP'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        STATION                NAME       DATE  TAVG  day  month  year
# 0  IN023351400  LUCKNOW AMAUSI, IN 1980-01-01    58    1      1  1980
# 1  IN023351400  LUCKNOW AMAUSI, IN 1980-01-02    59    2      1  1980
# 2  IN023351400  LUCKNOW AMAUSI, IN 1980-01-03    60    3      1  1980
# 3  IN023351400  LUCKNOW AMAUSI, IN 1980-01-04    54    4      1  1980
# 4  IN023351400  LUCKNOW AMAUSI, IN 1980-01-05    53    5      1  1980

# %%
df.drop(['STATION','NAME'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                                 DATE          TAVG           day  \
# count                          15817  15817.000000  15817.000000
# mean   2002-06-13 22:14:28.989062528     77.043624     15.715875
# min              1980-01-01 00:00:00     42.000000      1.000000
# 25%              1991-08-19 00:00:00     67.000000      8.000000
# 50%              2002-08-21 00:00:00     80.000000     16.000000
# 75%              2013-06-22 00:00:00     86.000000     23.000000
# max              2024-05-03 00:00:00    103.000000     31.000000
# std                              NaN     12.013249      8.786842
#
#               month          year
# count  15817.000000  15817.000000
# mean       6.503066   2001.952203
# min        1.000000   1980.000000
# 25%        3.000000   1991.000000
# 50%        7.000000   2002.000000
# 75%       10.000000   2013.000000
# max       12.000000   2024.000000
# std        3.458677     12.771586

# %%
df['tavg']=df['TAVG']

# %%
df.describe()
# Out:
#                                 DATE          TAVG           day  \
# count                          15817  15817.000000  15817.000000
# mean   2002-06-13 22:14:28.989062528     77.043624     15.715875
# min              1980-01-01 00:00:00     42.000000      1.000000
# 25%              1991-08-19 00:00:00     67.000000      8.000000
# 50%              2002-08-21 00:00:00     80.000000     16.000000
# 75%              2013-06-22 00:00:00     86.000000     23.000000
# max              2024-05-03 00:00:00    103.000000     31.000000
# std                              NaN     12.013249      8.786842
#
#               month          year          tavg
# count  15817.000000  15817.000000  15817.000000
# mean       6.503066   2001.952203     77.043624
# min        1.000000   1980.000000     42.000000
# 25%        3.000000   1991.000000     67.000000
# 50%        7.000000   2002.000000     80.000000
# 75%       10.000000   2013.000000     86.000000
# max       12.000000   2024.000000    103.000000
# std        3.458677     12.771586     12.013249

# %%
df.drop(['TAVG'],axis=1,inplace=True)

# %%
df[df['tavg'].isnull()]
# Out:
# Empty DataFrame
# Columns: [DATE, day, month, year, tavg]
# Index: []

# %%
df.isna().sum()
# Out:
# DATE     0
# day      0
# month    0
# year     0
# tavg     0
# dtype: int64

# %%
year_wise = pd.DataFrame(df.groupby(['year'])['tavg'].agg('mean').reset_index())

# %% [markdown]
# YEAR WISE TEMPAVG

# %%
year_wise = year_wise.set_index(year_wise['year'])
print(year_wise['tavg'].mean())
year_wise.head(2)
# Out:
# 76.917699712553
#       year       tavg
# year
# 1980  1980  76.830556
# 1981  1981  76.268698

# %%
plt.figure(figsize=(10,5))
plt.xlim([1980,2024])
sns.lineplot(x=year_wise.index,y=year_wise['tavg'],marker='o')
sns.lineplot(x =year_wise.index , y=[23.84255205877088]*len(year_wise.index),color='black',marker='o')
plt.legend(['yearly_avg',None,'mean_value'])
plt.show()

# %%
df.head(5)
# Out:
#         DATE  day  month  year  tavg
# 0 1980-01-01    1      1  1980    58
# 1 1980-01-02    2      1  1980    59
# 2 1980-01-03    3      1  1980    60
# 3 1980-01-04    4      1  1980    54
# 4 1980-01-05    5      1  1980    53

# %%
df_new = df[['DATE','tavg']]
df_new.columns=['ds','y']
df_new.tail(5)
# Out:
#               ds   y
# 15812 2024-04-28  91
# 15813 2024-04-29  90
# 15814 2024-04-30  89
# 15815 2024-05-02  83
# 15816 2024-05-03  87

# %%
df_new[df_new['ds']=='2018-12-31']
# Out:
#               ds   y
# 13874 2018-12-31  56

# %%
train = df_new[:10592]
test = df_new[10592:]

# %%
df.tail()
# Out:
#             DATE  day  month  year  tavg
# 15812 2024-04-28   28      4  2024    91
# 15813 2024-04-29   29      4  2024    90
# 15814 2024-04-30   30      4  2024    89
# 15815 2024-05-02    2      5  2024    83
# 15816 2024-05-03    3      5  2024    87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15817 entries, 0 to 15816
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    15817 non-null  datetime64[ns]
#  1   day     15817 non-null  int32
#  2   month   15817 non-null  int32
#  3   year    15817 non-null  int32
#  4   tavg    15817 non-null  int64
# dtypes: datetime64[ns](1), int32(3), int64(1)
# memory usage: 432.6 KB

# %%
import plotly.graph_objs as go
fig = go.Figure([

    go.Scatter(
        name='Train',
        x=df['DATE'],
        y=df['tavg'],
        mode='lines',
        marker=dict(color='blue'),
        line=dict(width=1),
        showlegend=True
    ),
    go.Scatter(
        name='Test',
        x=test['ds'],
        y=test['y'],
        mode='lines',
        marker=dict(color="orange"),
        line=dict(width=1),
        showlegend=True)])
fig.update_layout(
    yaxis_title='Temperature Avearage',
    title='Train and Test',
    hovermode="x"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4785a7fc-1fbe-4771-b21c-2d5d78654049" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4785a7fc-1fbe-4771-b21c-2d5d78654049")) {                    Plotly.newPlot(                        "4785a7fc-1fbe-4771-b21c-2d5d78654049",                        [{"line":{"width":1},"marker":{"color":"blue"},"mode":"lines","name":"Train","showlegend":true,"x":["1980-01-01T00:00:00","1980-01-02T00:00:00","1980-01-03T00:00:00","1980-01-04T00:00:00","1980-01-05T00:00:00","1980-01-06T00:00:00","1980-01-07T00:00:00","1980-01-08T00:00:00","1980-01-09T00:00:00","1980-01-10T00:00:00","1980-01-11T00:00:00","1980-01-12T00:00:00","1980-01-13T00:00:00","1980-01-14T00:00:00","1980-01-15T00:00:00","1980-01-16T00:00:00","1980-01-17T00:00:00","1980-01-18T00:00:00","1980-01-19T00:00:00","1980-01-20T00:00:00","1980-01-21T00:00:00","1980-01-22T00:00:00","1980-01-23T00:00:00","1980-01-24T00:00:00","1980-01-25T00:00:00","1980-01-26T00:00:00","1980-01-27T00:00:00","1980-01-28T00:00:00","1980-01-29T00:00:00","1980-01-30T00:00:00","1980-01-31T00:00:00","1980-02-01T00:00:00","1980-02-02T00:00:00","1980-02-04T00:00:00","1980-02-05T00:00:00","1980-02-06T00:00:00","1980-02-07T00:00:00","1980-02-08T00:00:00","1980-02-09T00:00:00","1980-02-10T00:00:00","1980-02-11T00:00:00","1980-02-12T00:00:00","1980-02-13T00:00:00","1980-02-14T00:00:00","1980-02-15T00:00:00","1980-02-16T00:00:00","1980-02-17T00:00:00","1980-02-18T00:00:00","1980-02-19T00:00:00","1980-02-20T00:00:00","1980-02-21T00:00:00","1980-02-22T00:00:00","1980-02-23T00:00:00","1980-02-24T00:00:00","1980-02-25T00:00:00","1980-02-26T00:00:00","1980-02-27T00:00:00","1980-02-28T00:00:00","1980-02-29T00:00:00","1980-03-01T00:00:00","1980-03-02T00:00:00","1980-03-03T00:00:00","1980-03-04T00:00:00","1980-03-05T00:00:00","1980-03-06T00:00:00","1980-03-07T00:00:00","1980-03-08T00:00:00","1980-03-09T00:00:00","1980-03-10T00:00:00","1980-03-11T00:00:00","1980-03-12T00:00:00","1980-03-13T00:00:00","1980-03-14T00:00:00","1980-03-15T00:00:00","1980-03-16T00:00:00","1980-03-17T00:00:00","1980-03-18T00:00:00","1980-03-19T00:00:00","1980-03-20T00:00:00","1980-03-21T00:00:00","1980-03-22T00:00:00","1980-03-23T00:00:00","1980-03-24T00:00:00","1980-03-25T00:00:00","1980-03-26T00:00:00","1980-03-27T00:00:00","1980-03-28T00:00:00","1980-03-29T00:00:00","1980-03-30T00:00:00","1980-03-31T00:00:00","1980-04-01T00:00:00","1980-04-02T00:00:00","1980-04-03T00:00:00","1980-04-04T00:00:00","1980-04-05T00:00:00","1980-04-06T00:00:00","1980-04-07T00:00:00","1980-04-08T00:00:00","1980-04-09T00:00:00","1980-04-11T00:00:00","1980-04-12T00:00:00","1980-04-13T00:00:00","1980-04-14T00:00:00","1980-04-15T00:00:00","1980-04-16T00:00:00","1980-04-17T00:00:00","1980-04-18T00:00:00","1980-04-19T00:00:00","1980-04-20T00:00:00","1980-04-21T00:00:00","1980-04-22T00:00:00","1980-04-23T00:00:00","1980-04-24T00:00:00","1980-04-25T00:00:00","1980-04-26T00:00:00","1980-04-27T00:00:00","1980-04-29T00:00:00","1980-04-30T00:00:00","1980-05-01T00:00:00","1980-05-02T00:00:00","1980-05-03T00:00:00","1980-05-04T00:00:00","1980-05-05T00:00:00","1980-05-06T00:00:00","1980-05-07T00:00:00","1980-05-08T00:00:00","1980-05-09T00:00:00","1980-05-10T00:00:00","1980-05-11T00:00:00","1980-05-12T00:00:00","1980-05-13T00:00:00","1980-05-14T00:00:00","1980-05-15T00:00:00","1980-05-16T00:00:00","1980-05-17T00:00:00","1980-05-18T00:00:00","1980-05-19T00:00:00","1980-05-20T00:00:00","1980-05-21T00:00:00","1980-05-22T00:00:00","1980-05-23T00:00:00","1980-05-24T00:00:00","1980-05-25T00:00:00","1980-05-26T00:00:00","1980-05-27T00:00:00","1980-05-28T00:00:00","1980-05-29T00:00:00","1980-05-30T00:00:00","1980-05-31T00:00:00","1980-06-01T00:00:00","1980-06-02T00:00:00","1980-06-03T00: ...

# %% [markdown]
# THE ABOVE PLOT SHOWS THE DISTRIBUTION OF TRAINING AND TESTING DATA

# %% [markdown]
# USING PROPHET TO TRAIN THE MODEL

# %%
from prophet import Prophet
model=Prophet()

# %%
model.fit(train)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj348fwl1/bcrf4pp_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj348fwl1/w1ynnv69.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15414', 'data', 'file=/tmp/tmpj348fwl1/bcrf4pp_.json', 'init=/tmp/tmpj348fwl1/w1ynnv69.json', 'output', 'file=/tmp/tmpj348fwl1/prophet_modelzr24fgmw/prophet_model-20240506175749.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:57:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:57:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test.shape
# Out:
# (5225, 2)

# %%
test.tail(2)
# Out:
#               ds   y
# 15815 2024-05-02  83
# 15816 2024-05-03  87

# %%
new_df= model.make_future_dataframe(periods=5225)
new_df.tail(5)
# Out:
#               ds
# 15812 2024-04-15
# 15813 2024-04-16
# 15814 2024-04-17
# 15815 2024-04-18
# 15816 2024-04-19

# %%
result = model.predict(new_df)
result.tail(5)
# Out:
#               ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 15812 2024-04-15  76.487359   76.308871   95.301779    67.805718    85.233184
# 15813 2024-04-16  76.487220   75.099344   95.594056    67.802122    85.236141
# 15814 2024-04-17  76.487081   76.032096   95.759964    67.798527    85.239098
# 15815 2024-04-18  76.486942   76.029692   95.788282    67.794932    85.242055
# 15816 2024-04-19  76.486803   76.582406   96.335603    67.791337    85.245012
#
#        additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 15812        8.840984              8.840984              8.840984 -0.105567
# 15813        9.113482              9.113482              9.113482 -0.113035
# 15814        9.522754              9.522754              9.522754  0.033941
# 15815        9.821182              9.821182              9.821182  0.087825
# 15816       10.019927             10.019927             10.019927  0.059624
#
#        weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 15812     -0.105567     -0.105567  8.946551      8.946551      8.946551
# 15813     -0.113035     -0.113035  9.226517      9.226517      9.226517
# 15814      0.033941      0.033941  9.488812      9.488812      9.488812
# 15815      0.087825      0.087825  9.733357      9.733357      9.733357
# 15816      0.059624      0.059624  9.960303      9.960303      9.960303
#
#        multiplicative_terms  multiplicative_terms_lower  \
# 15812                   0.0                         0.0
# 15813                   0.0                         0.0
# 15814                   0.0                         0.0
# 15815                   0.0                         0.0
# 15816                   0.0                         0.0
#
#        multiplicative_terms_upper       yhat
# 15812                         0.0  85.328343
# 15813                         0.0  85.600702
# 15814                         0.0  86.009835
# 15815                         0.0  86.308123
# 15816                         0.0  86.506729

# %%
data = result[['ds','trend','yhat','yhat_lower','yhat_upper']]
data.columns=['date','trend','final_outcome(predicted)','final_outcome_lower_limit','final_outcome_upper_limit']
data.tail()
# Out:
#             date      trend  final_outcome(predicted)  \
# 15812 2024-04-15  76.487359                 85.328343
# 15813 2024-04-16  76.487220                 85.600702
# 15814 2024-04-17  76.487081                 86.009835
# 15815 2024-04-18  76.486942                 86.308123
# 15816 2024-04-19  76.486803                 86.506729
#
#        final_outcome_lower_limit  final_outcome_upper_limit
# 15812                  76.308871                  95.301779
# 15813                  75.099344                  95.594056
# 15814                  76.032096                  95.759964
# 15815                  76.029692                  95.788282
# 15816                  76.582406                  96.335603

# %%
df.tail(20)
# Out:
#             DATE  day  month  year  tavg
# 15797 2024-04-13   13      4  2024    86
# 15798 2024-04-14   14      4  2024    86
# 15799 2024-04-15   15      4  2024    90
# 15800 2024-04-16   16      4  2024    89
# 15801 2024-04-17   17      4  2024    86
# 15802 2024-04-18   18      4  2024    89
# 15803 2024-04-19   19      4  2024    91
# 15804 2024-04-20   20      4  2024    91
# 15805 2024-04-21   21      4  2024    87
# 15806 2024-04-22   22      4  2024    90
# 15807 2024-04-23   23      4  2024    90
# 15808 2024-04-24   24      4  2024    88
# 15809 2024-04-25   25      4  2024    89
# 15810 2024-04-26   26      4  2024    94
# 15811 2024-04-27   27      4  2024    89
# 15812 2024-04-28   28      4  2024    91
# 15813 2024-04-29   29      4  2024    90
# 15814 2024-04-30   30      4  2024    89
# 15815 2024-05-02    2      5  2024    83
# 15816 2024-05-03    3      5  2024    87

# %%
import plotly.graph_objs as go
fig = go.Figure([

    go.Scatter(
        name='Test_Actual',
        x=test['ds'],
        y=test['y'],
        mode='lines',
        marker=dict(color='orange'),
        line=dict(width=3),
        showlegend=True
    ),
    go.Scatter(
        name='Test_predicted',
        x=data[10592:]['date'],
        y=data[10592:]['final_outcome(predicted)'],
        mode='lines',
        marker=dict(color="red"),
        line=dict(width=1),
        showlegend=True),
    go.Scatter(
00","1980-02-24T00:00:00","1980-02-25T00:00:00","1980-02-26T00:00:00","1980-02-27T00:00:00","1980-02-28T00:00:00","1980-02-29T00:00:00","1980-03-01T00:00:00","1980-03-02T00:00:00","1980-03-03T00:00:00","1980-03-04T00:00:00","1980-03-05T00:00:00","1980-03-06T00:00:00","1980-03-07T00:00:00","1980-03-08T00:00:00","1980-03-09T00:00:00","1980-03-10T00:00:00","1980-03-11T00:00:00","1980-03-12T00:00:00","1980-03-13T00:00:00","1980-03-14T00:00:00","1980-03-15T00:00:00","1980-03-16T00:00:00","1980-03-17T00:00:00","1980-03-18T00:00:00","1980-03-19T00:00:00","1980-03-20T00:00:00","1980-03-21T00:00:00","1980-03-22T00:00:00","1980-03-23T00:00:00","1980-03-24T00:00:00","1980-03-25T00:00:00","1980-03-26T00:00:00","1980-03-27T00:00:00","1980-03-28T00:00:00","1980-03-29T00:00:00","1980-03-30T00:00:00","1980-03-31T00:00:00","1980-04-01T00:00:00","1980-04-02T00:00:00","1980-04-03T00:00:00","1980-04-04T00:00:00","1980-04-05T00:00:00","1980-04-06T00:00:00","1980-04-07T00:00:00","1980-04-08T00:00:00","1980-04-09T00:00:00","1980-04-11T00:00:00","1980-04-12T00:00:00","1980-04-13T00:00:00","1980-04-14T00:00:00","1980-04-15T00:00:00","1980-04-16T00:00:00","1980-04-17T00:00:00","1980-04-18T00:00:00","1980-04-19T00:00:00","1980-04-20T00:00:00","1980-04-21T00:00:00","1980-04-22T00:00:00","1980-04-23T00:00:00","1980-04-24T00:00:00","1980-04-25T00:00:00","1980-04-26T00:00:00","1980-04-27T00:00:00","1980-04-29T00:00:00","1980-04-30T00:00:00","1980-05-01T00:00:00","1980-05-02T00:00:00","1980-05-03T00:00:00","1980-05-04T00:00:00","1980-05-05T00:00:00","1980-05-06T00:00:00","1980-05-07T00:00:00","1980-05-08T00:00:00","1980-05-09T00:00:00","1980-05-10T00:00:00","1980-05-11T00:00:00","1980-05-12T00:00:00","1980-05-13T00:00:00","1980-05-14T00:00:00","1980-05-15T00:00:00","1980-05-16T00:00:00","1980-05-17T00:00:00","1980-05-18T00:00:00","1980-05-19T00:00:00","1980-05-20T00:00:00","1980-05-21T00:00:00","1980-05-22T00:00:00","1980-05-23T00:00:00","1980-05-24T00:00:00","1980-05-25T00:00:00","1980-05-26T00:00:00","1980-05-27T00:00:00","1980-05-28T00:00:00","1980-05-29T00:00:00","1980-05-30T00:00:00","1980-05-31T00:00:00","1980-06-01T00:00:00","1980-06-02T00:00:00","1980-06-03T00:00:00","1980-06-04T00:0 ...

# %%
test['predicted'] = data[15200:]['final_outcome(predicted)']
# Out:
# <ipython-input-99-bb9cfd11aec1>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test['mse'] = (test['y']-test['predicted'])**2
# Out:
# <ipython-input-100-37b4b31eff52>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test['smape'] = abs(test['y']-test['predicted'])/(abs(test['y']+test['predicted']))/2
# Out:
# <ipython-input-101-5f7ae0c62ee3>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test['mape'] = abs((test['y']-test['predicted'])/test['y'])
# Out:
# <ipython-input-102-b62f9bce4cb2>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print('MAPE = ',test['mape'].mean()*100)
print('SMAPE = ',test['smape'].mean()*100)
# Out:
# MAPE =  4.745539926222272
# SMAPE =  1.1845061037019309
